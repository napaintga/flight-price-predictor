# %% [markdown]
# # XGBoost
#
# XGBoost regression with the shared selected features. The cell skips training if xgboost is not installed.
#
# All forecasting notebooks use the same selected columns from `forecast_features.py`.

# %%
from pathlib import Path
import sys
from types import SimpleNamespace

repo_root = Path.cwd().resolve()
while repo_root != repo_root.parent and not (repo_root / 'backend' / 'ml').exists():
    repo_root = repo_root.parent

ml_dir = repo_root / 'backend' / 'ml'
if str(ml_dir) not in sys.path:
    sys.path.insert(0, str(ml_dir))

from forecast_features import (
    FEATURE_COLUMNS, NUMERIC_FEATURES, CATEGORICAL_FEATURES, REMOVED_FEATURES,
    FEATURE_IMPORTANCE_SOURCE, FEATURE_SELECTION_NOTES, TARGET_COLUMN,
)

args = SimpleNamespace(
    input=str(repo_root / 'etl' / 'exports' / 'flights_features_all.csv'),
    output=str(repo_root / 'backend' / 'ml' / 'models' / 'xgboost'),
    sample_size=0,
    limit_rows=None,
    test_size=0.2,
    random_state=42,
    n_jobs=1,
)

print('Target:', TARGET_COLUMN)
print('Selected features:', FEATURE_COLUMNS)
# Out:
# Target: price
# Selected features: ['days_to_departure', 'stops', 'duration_minutes', 'distance_km', 'depart_hour', 'recent_price_trend_per_day', 'travel_class', 'airline', 'origin', 'destination', 'arrival_time', 'search_month', 'depart_dow', 'depart_month']

# %%
import pandas as pd

display(pd.DataFrame([{'feature': k, 'source_importance': v} for k, v in FEATURE_IMPORTANCE_SOURCE.items()]))
display(pd.DataFrame({'numeric_feature': NUMERIC_FEATURES}))
display(pd.DataFrame({'categorical_feature': CATEGORICAL_FEATURES}))
display(pd.DataFrame({'removed_feature': REMOVED_FEATURES}))
display(pd.DataFrame({'selection_note': FEATURE_SELECTION_NOTES}))
# Out:
#                        feature  source_importance
# 0                 travel_class              0.519
# 1                        stops              0.153
# 2                      airline              0.150
# 3            days_to_departure              0.038
# 4                       origin              0.032
# 5             duration_minutes              0.028
# 6                  distance_km              0.020
# 7                  depart_hour              0.017
# 8                  destination              0.014
# 9   recent_price_trend_per_day              0.010
# 10                arrival_time              0.006
# 11                search_month              0.006
# 12                  depart_dow              0.006
# 13                depart_month              0.003
#               numeric_feature
# 0           days_to_departure
# 1                       stops
# 2            duration_minutes
# 3                 distance_km
# 4                 depart_hour
# 5  recent_price_trend_per_day
#   categorical_feature
# 0        travel_class
# 1             airline
# 2              origin
# 3         destination
# 4        arrival_time
# 5        search_month
# 6          depart_dow
# 7        depart_month
#       removed_feature
# 0           flight_id
# 1      departure_date
# 2      departure_time
# 3    passengers_total
# 4           trip_type
# 5         origin_type
# 6    destination_type
# 7   depart_is_weekend
# 8       depart_season
# 9          search_dow
# 10  search_is_weekend
# 11      search_season
# 12       price_per_km
# 13     price_per_hour
# 14      revenue_proxy
# 15      price_segment
#                                       selection_note
# 0  Keep depart_hour instead of departure_time bec...
# 1  Keep depart_dow instead of depart_is_weekend b...
# 2  Keep search_month instead of search_season bec...
# 3  Keep arrival_time because it describes arrival...
# 4  Remove price-derived columns to avoid target l...
# 5  Add recent_price_trend_per_day as a causal loc...

# %%
try:
    import xgboost as xgb
except ImportError as exc:
    print('xgboost is not installed:', exc)
else:
    from forecast_model_utils import train_sklearn_forecaster
    result = train_sklearn_forecaster(
        model_name='xgboost',
        estimator=xgb.XGBRegressor(
            n_estimators=420,
            max_depth=8,
            learning_rate=0.045,
            subsample=0.92,
            colsample_bytree=0.92,
            min_child_weight=1.0,
            reg_lambda=1.0,
            objective='reg:squarederror',
            tree_method='hist',
            random_state=args.random_state,
            n_jobs=args.n_jobs,
        ),
        input_path=args.input,
        output_dir=args.output,
        sample_size=args.sample_size,
        limit_rows=args.limit_rows,
        test_size=args.test_size,
        random_state=args.random_state,
    )
    print(result['metrics'])
    display(result['feature_importance'].head(20))
    display(result['predictions'].head(20))
# Out:
# {'mae': 194.89786056786733, 'rmse': 361.77357400307017, 'r2': 0.7805140999343687, 'mape_pct': 24.486155821819374, 'model': 'xgboost', 'target': 'log1p(price)', 'rows_in_file_or_read': 5150048, 'rows_after_cleaning': 3757116, 'rows_used_for_model': 3757116, 'train_rows': 3005692, 'test_rows': 751424, 'refit_on_full_data': True, 'final_fit_rows': 3757116, 'features': ['days_to_departure', 'stops', 'duration_minutes', 'distance_km', 'depart_hour', 'recent_price_trend_per_day', 'travel_class', 'airline', 'origin', 'destination', 'arrival_time', 'search_month', 'depart_dow', 'depart_month'], 'removed_columns': ['flight_id', 'departure_date', 'departure_time', 'passengers_total', 'trip_type', 'origin_type', 'destination_type', 'depart_is_weekend', 'depart_season', 'search_dow', 'search_is_weekend', 'search_season', 'price_per_km', 'price_per_hour', 'revenue_proxy', 'price_segment'], 'training_scope': {'origin_countries': ('GB', 'PL'), 'destination_countries': ('IT', 'FR'), 'trip_types': ('one-way',), 'travel_classes': ('Economy Class', 'Business Class')}, 'normalization': {'version': 'travel-class-country-trip-airline-v1', 'airline': 'canonical aliases, deduplicated and sorted multi-carrier labels', 'travel_class': 'canonical display labels', 'trip_type': 'canonical one-way/round-trip labels', 'recent_price_trend_per_day': 'causal slope from previous local price observations'}}
#                        feature  importance
# 7                      airline    0.881170
# 6                 travel_class    0.038013
# 8                       origin    0.028248
# 1                        stops    0.021525
# 9                  destination    0.018548
# 10                arrival_time    0.002829
# 11                search_month    0.002345
# 12                  depart_dow    0.002246
# 3                  distance_km    0.001243
# 2             duration_minutes    0.001137
# 4                  depart_hour    0.001036
# 0            days_to_departure    0.000793
# 13                depart_month    0.000757
# 5   recent_price_trend_per_day    0.000110
#                                                  flight_id departure_date  \
# 5044071  46695fc9a4cc69904d0490ff6592aaadd6986fe67968e1...     2026-04-27
# 276860   3e118a975f634830e5f11a51b247bac7cceab499b30666...     2026-04-08
# 2290487  87dbf3a752d8346b588de9cd9c9c8138f984dcc8a174c2...     2026-04-21
# 955003   ed63c0ac4a03f80512129289e3014ab123b6705a2e7b79...     2026-04-07
# 4172315  da6bee0903e9466429a62a109b2a57ebf0493690f027bb...     2026-03-14
# 318575   c029418f6312076f32424368bbc81241d536664a74b2b0...     2026-04-12
# 1059096  141f7ac3a7fa2ab306e2fd2e82c43fb6e0e5426d110d27...     2026-04-19
# 2380169  3dd62b55c6886379dea0339ab548e010d6a4cf3bb09f7d...     2026-05-01
# 5115410  fde2906d73ce96570764238fac1407aa000a49ecc57833...     2026-04-07
# 657436   fba78a4a2c0809bbe34da93cfe0fd91856c24c7e230238...     2026-04-08
# 1490577  d1dea31fc3913e5c4b8547870fb2ede9a3d759102d0582...     2026-04-11
# 2261836  c85c1e5275d1907c820bb41f2c1a950565c07ad52fa48a...     2026-05-15
# 1762154  8654cbc0759827de1f2bafc50fe5a0d97306c79a2a13ff...     2026-04-16
# 4476959  128fa33aee27e51b3653fca32a808ab868bf88360d5e5b...     2026-04-18
# 4471560  0c37844676e8583d58227b24691215ff4d7d23d569763a...     2026-04-17
# 3011673  83e24224d52e94d90ff74eac265351ed98b738a7095bfd...     2026-03-23
# 1300140  3205a3b784a1be95802a03fc95c9302582601fad1aaf73...     2026-04-18
# 3529778  1d691ad5dc12ff34e7186e7f34f50a26925104d578bb2f...     2026-04-21
# 2650892  b78c7f61ef35b46f2c5cbb4dc50dd28de0672499dd3e3b...     2026-03-07
# 2732477  9790237e8fb342e6830d6c3e32689e1a11d7b68609e944...     2026-03-16
#
#         origin destination                             airline  \
# 5044071    WAW         FCO                   Austrian Airlines
# 276860     LHR         CDG                           Lufthansa
# 2290487    LGW         FCO                          Air France
# 955003     LHR         NCE                           Lufthansa
# 4172315    KRK         CDG                     Air France, KLM
# 318575     MAN         CDG                     British Airways
# 1059096    KRK         MXP             Air Dolomiti, Lufthansa
# 2380169    LGW         NCE                           Norwegian
# 5115410    MAN         MXP                           Eurowings
# 657436     LGW         MXP  Air Dolomiti, Eurowings, Lufthansa
# 1490577    KRK         NCE                     Air France, KLM
# 2261836    KRK         NCE                           Lufthansa
# 1762154    MAN         MXP                              Luxair
# 4476959    WAW         NCE                               SWISS
# 4471560    LHR         VCE                           Lufthansa
# 3011673    KRK         MXP               Scandinavian Airlines
# 1300140    LHR         FCO                              Aegean
# 3529778    LHR         NCE                          Air France
# 2650892    LHR         MXP                               SWISS
# 2732477    MAN         FCO                          Air France
#
#            travel_class  actual_price  predicted_price  absolute_error  \
# 5044071  Business Class         566.0       692.640015          126.64
# 276860   Business Class         705.0       958.190002          253.19
# 2290487  Business Class         906.0      1004.059998           98.06
# 955003    Economy Class         389.0       406.839996           17.84
# 4172315  Business Class         682.0       552.309998          129.69
# 318575   Business Class         713.0       764.510010           51.51
# 1059096  Business Class        3081.0       975.010010         2105.99
# 2380169   Economy Class         244.0       304.299988           60.30
# 5115410  Business Class        1203.0      1091.859985          111.14
# 657436    Economy Class        1774.0      1179.750000          594.25
# 1490577  Business Class        1298.0      1116.349976          181.65
# 2261836  Business Class         763.0       714.500000           48.50
# 1762154  Business Class        1117.0      1221.369995          104.37
# 4476959   Economy Class         424.0       367.559998           56.44
# 4471560  Business Class         568.0       616.989990           48.99
# 3011673   Economy Class         410.0       326.950012           83.05
# 1300140   Economy Class         218.0       375.989990          157.99
# 3529778  Business Class         906.0       953.530029           47.53
# 2650892   Economy Class         193.0       265.510010           72.51
# 2732477   Economy Class         221.0       250.399994           29.40
#
#          absolute_error_pct
# 5044071               22.38
# 276860                35.91
# 2290487               10.82
# 955003                 4.59
# 4172315               19.02
# 318575                 7.22
# 1059096               68.35
# 2380169               24.71
# 5115410                9.24
# 657436                33.50
# 1490577               13.99
# 2261836                6.36
# 1762154                9.34
# 4476959               13.31
# 4471560                8.63
# 3011673               20.26
# 1300140               72.47
# 3529778                5.25
# 2650892               37.57
# 2732477               13.30
